# %%
import pandas as pd 
#yeni kütüphane eklendiğinde bu satır tekrar çalıştırılacak
import numpy as np

# %%
#veri setini dahil ettik
df = pd.read_csv('houses_Madrid.csv')

# %%
#veri setinin ilk 10 satırını gösterdik
df.head(10).T
# Out:
#                                                                               0  \
# Unnamed: 0                                                                    0
# id                                                                        21742
# title                                     Piso en venta en calle de Godella, 64
# subtitle                                                  San Cristóbal, Madrid
# sq_mt_built                                                                64.0
# sq_mt_useful                                                               60.0
# n_rooms                                                                       2
# n_bathrooms                                                                 1.0
# n_floors                                                                    NaN
# sq_mt_allotment                                                             NaN
# latitude                                                                    NaN
# ...

# %%
# veri setinin kaç satır ve sütundan oluştuğuna bakalım
df.shape
# Out:
# (21742, 58)

# %%
#veri setinin toplam kaç veriden oluştuğuna bakalım
df.size
# Out:
# 1261036

# %%
#veri setini inceler
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21742 entries, 0 to 21741
# Data columns (total 58 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    21742 non-null  int64
#  1   id                            21742 non-null  int64
#  2   title                         21742 non-null  object
#  3   subtitle                      21742 non-null  object
#  4   sq_mt_built                   21616 non-null  float64
#  5   sq_mt_useful                  8228 non-null   float64
#  6   n_rooms                       21742 non-null  int64
#  7   n_bathrooms                   21726 non-null  float64
#  8   n_floors                      1437 non-null   float64
#  9   sq_mt_allotment               1432 non-null   float64
#  10  latitude                      0 non-null      float64
#  11  longitude                     0 non-null      float64
# ...

# %%
df.describe().T #veri setrindeki özniteliklere ait toplam veri sayısı, verilerin ortalaması minimum değerleri gibi bilgilerini inceleyelim
#.T satır ve sütünları yer değiştirir
# Out:
#                        count           mean            std         min  \
# Unnamed: 0           21742.0   10870.500000    6276.519112         0.0
# id                   21742.0   10871.500000    6276.519112         1.0
# sq_mt_built          21616.0     146.920892     134.181865        13.0
# sq_mt_useful          8228.0     103.458192      88.259192         1.0
# n_rooms              21742.0       3.005749       1.510497         0.0
# n_bathrooms          21726.0       2.091687       1.406992         1.0
# n_floors              1437.0       3.128740       0.907713         1.0
# sq_mt_allotment       1432.0     241.692737     247.484853         1.0
# latitude                 0.0            NaN            NaN         NaN
# longitude                0.0            NaN            NaN         NaN
# portal                   0.0            NaN            NaN         NaN
# door                     0.0            NaN            NaN         NaN
# ...

# %%
df.isnull().sum() #boş verileri gösterir
# Out:
# Unnamed: 0                          0
# id                                  0
# title                               0
# subtitle                            0
# sq_mt_built                       126
# sq_mt_useful                    13514
# n_rooms                             0
# n_bathrooms                        16
# n_floors                        20305
# sq_mt_allotment                 20310
# latitude                        21742
# longitude                       21742
# raw_address                      5465
# is_exact_address_hidden             0
# street_name                      5905
# street_number                   15442
# portal                          21742
# floor                            2607
# is_floor_under                   1170
# door                            21742
# neighborhood_id                     0
# operation                           0
# rent_price                          0
# rent_price_by_area              21742
# is_rent_price_known                 0
# ...

# %%
df=df.dropna(subset=['has_private_parking','has_public_parking','is_kitchen_equipped','is_furnished','are_pets_allowed','rent_price_by_area','door','portal','longitude','latitude'],inplace=True)
#sütün ve satırlardaki boş verileri kaldırır
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df=df.dropna(subset=['has_private_parking','has_public_parking','is_kitchen_equipped','is_furnished','are_pets_allowed','rent_price_by_area','door','portal','longitude','latitude'],inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'dropna'
